# %%
# %%bash
# # Clone or update
# if [ -d /content/MCP_Math ]; then
#   cd /content/MCP_Math && git pull -q && echo "Updated: $(git log -1 --oneline)"
# else
#   git clone -q https://github.com/azzindani/MCP_Math.git /content/MCP_Math
#   echo "Cloned: $(cd /content/MCP_Math && git log -1 --oneline)"
# fi
#
# # Install deps (uv + uv sync)
# bash /content/MCP_Math/remote_install.sh

# %%
# %%bash
# bash /content/MCP_Math/remote_launch.sh

# %%
# %%bash
# bash /content/MCP_Math/remote_launch.sh stop
